# %%
# !git clone https://github.com/Bungeetech/internship-test2.git
# Out:
# Cloning into 'internship-test2'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 26 (delta 2), reused 0 (delta 0), pack-reused 19
# Unpacking objects: 100% (26/26), done.

# %%
import pandas as pd

# %% [markdown]
# ## Question 1

# %%
df = pd.read_csv('/content/internship-test2/input/question-1/main.csv')
df.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit
# 0              36   kg
# 1              23   kg
# 2              34   kg
# 3              23   kg
# 4              34   kg

# %%
df['price_new'] = df['price'].fillna(df.groupby('product_description')['price'].transform('mean'))
df.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit  price_new
# 0              36   kg       2.99
# 1              23   kg       2.99
# 2              34   kg       2.99
# 3              23   kg       2.99
# 4              34   kg       2.99

# %%
df.to_csv('/content/internship-test2/output/answer-1/main.csv', index=False)

# %% [markdown]
# ## Question 2

# %%
df = pd.read_csv('/content/internship-test2/input/question-2/main.csv')
df.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit
# 0              36   kg
# 1              23   kg
# 2              34   kg
# 3              23   kg
# 4              34   kg

# %%
df["sales_amount"]=df["sales_quantity"].where(df["unit"] !="pcs",df["product_description"].str.split("-",expand=True)[1].astype("float") *
df["sales_quantity"])
df.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit  sales_amount
# 0              36   kg          36.0
# 1              23   kg          23.0
# 2              34   kg          34.0
# 3              23   kg          23.0
# 4              34   kg          34.0

# %%
df.to_csv('/content/internship-test2/output/answer-2/main.csv', index=False)

# %% [markdown]
# ## Question 3

# %%
df = pd.read_csv('/content/internship-test2/input/question-3/main.csv')
df.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
df = df.sort_values(by=['Red Cards', 'Yellow Cards'])
df.head()
# Out:
#            Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 2       Denmark      4               10                10             50.0%
# 5       Germany     10               32                32             47.8%
# 3       England      5               11                18             50.0%
# 8   Netherlands      2               12                36             25.0%
# 15      Ukraine      2                7                26             21.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 2             20.0%                          27             1              0
# 5             15.6%                          80             2              1
# 3             17.2%                          40             0              0
# 8              4.1%                          60             2              0
# 15             6.0%                          38             0              0
#
# ...

# %%
df.to_csv('/content/internship-test2/output/answer-3/main.csv', index=False)
